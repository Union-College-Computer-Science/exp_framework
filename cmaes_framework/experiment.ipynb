# %% [markdown]
# Experiment 1
# By:
# Description of what's changed:

# %%
# run experiment
import best_individual_latest
best_individual_latest.visualize_best('s', 's', 'cmaes_framework/latest.csv')
# get graphs
# display graphs
# Out:
# Using Evolution Gym Simulator v2.2.5
# Status: Using GLEW 2.2.0
# 2025-04-13 21:43:38.466 Python[84608:69009162] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-04-13 21:43:38.466 Python[84608:69009162] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# Status: Using GLEW 2.2.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# ...

# %%
# run experiment
import best_individual_latest
best_individual_latest.visualize_best('l', 's', 'cmaes_framework/latest.csv')
# get graphs
# display graphs
# Out:
# Status: Using GLEW 2.2.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# Status: Using GLEW 2.2.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# rps: 50 | avg rps: 50.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # run experiment
#       2 import best_individual_latest
# ----> 3 best_individual_latest.visualize_best('l', 's', 'cmaes_framework/latest.csv')
# ...
